# %%
import razor

# %%
razor.api.marketplace.blocks()
# Out:
# PlatformMarketplaceBlockList(blocks=[PlatformMarketplaceBlock(id='195fd459-3fdb-41f2-9b99-a2c933e8d4f6', git_link='https://github.com/razorthinksoftware/razor-blocks/tree/master/Jenoptik_bundle_market', type='BUNDLE', path='/razorthink-ai/marketplace/downloads/Jenoptik_bundle_market/Jenoptik_bundle_market.zip', bundle_name='Jenoptik_bundle_market', publisher_tenant_name='rzt', message=None, data=Data(id=None, name='Jenoptik_bundle_market', label=None, source_bundle_path='/razorthink-ai/marketplace/downloads/Jenoptik_bundle_market/Jenoptik_bundle_market.zip', bundle_name=None, version='0.0.1', description='', tags=[], author='', publisher='', blocks=[Block(name='BuildModel', description='', label='BuildModel', active=True, category='jenoptik_bundle', technology='PYTHON', permission=None, default_execution_mode='BlockExecutor', inputs=[Input(name='image_channels', doc=None, label=None, data_type='integer', required=False, data_flow_type='atomic', default=0, render_type=None, request_de
# ...
