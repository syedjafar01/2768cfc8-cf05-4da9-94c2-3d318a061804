# %%
import pandas as pd
import numpy as np
import re

# %%
from razor import project_space_path as psp

# %%
new_prod_maps = pd.read_csv('Dist2614.csv')

# %%
d_newprodmap = new_prod_maps[['Product','Cod_Prod']].set_index('Cod_Prod').to_dict()['Product']

# %% [raw]
# upn = pd.read_csv('sdata/Fidelity Dummy - UniqueProdNames.csv')
#
# upn.reset_index(drop=True, inplace=True)
#
# upn['Product Name'] = upn['Product Name'].apply(lambda x: re.sub('[^a-zA-Z0-9\s]',' ',x))
#
# upn['Product Name'] = upn['Product Name'].apply(lambda x: re.sub('\s{1,}','_',x))
#
# sorted(list(upn['Product Name'].unique())) == sorted(list(new_prod_maps['Product'].unique()))
#
# upn.to_csv('New_UniqueProdsMap.csv', index=False)

# %%
pd.read_csv('DataGeneration/meta_data/latest_purchase_history.csv')
# Out:
#         Unnamed: 0 Customer_ID Purchase_Date  Product_ID  Age_Group  \
# 0                0    A0000001    2013-04-01     4746218          5
# 1                1    A0000002    2015-02-01     4536150          5
# 2                2    A0000003    2016-02-01     4779697          5
# 3                3    A0000004    2016-05-01     4871713          5
# 4                4    A0000006    2015-05-01     4908519          5
# ...            ...         ...           ...         ...        ...
# 803727      803727    A0676367    2016-09-01     4871713          1
# 803728      803728    A0676368    2016-09-01     4697906          1
# 803729      803729    A0676369    2015-10-01     4908519          3
# 803730      803730    A0676370    2015-11-01     4697906          3
# 803731      803731    A0676370    2015-11-01     4779697          3
#
#         Antiquity_Group            Income_Group Gender_Group Profession_Group
# ...

# %%
d_newprodmap
# Out:
# {201: 'Standard_Everyday_Checking_Account',
#  601: 'Standard_Business_Checking_Account',
#  301: 'Savings',
#  9991: 'Standard_Flex_Credit_Card',
#  9993: 'Standard_Unlimited_Credit_Card',
#  2302: 'Premium_Business_Checking_Account',
#  2205: '72_mo_fixed_rate_Business_Loan',
#  704: '48_Months_CD',
#  2601: 'Costco_Visa_Debit_Card',
#  9992: '60_Months_CD',
#  1011: '60_mo_fixed_rate_Business_Loan',
#  2301: '84_Months_CD',
#  2704: 'Premier_Plus_Everyday_Checking_Account',
#  2705: '36_Months_CD',
#  2602: 'Domestic_wire_transfers',
#  2503: '84_mo_fixed_rate_Business_Loan',
#  2501: 'Dunkin_Donuts_Prepaid_Card',
#  2707: 'Performance_Business_Checking_Account',
#  706: '72_mo_variable_rate_Business_Loan',
#  2701: '84_mo_variable_rate_Business_Loan',
#  1804: 'International_wire_transfers',
#  2102: '60_mo_variable_rate_Business_Loan',
#  1020: 'Empire_Business_Unlimited_Credit_Card',
#  2106: '42_Months_CD',
#  2201: 'Platinum_Banking_Checking_Account',
# ...
