# %%
from razor.api import dl_models

# %%
model_names = ["split_1st_concat_last_group", "optimizer_zero_lr", "2_optmizer_same_subgraph",
               "split_1st_BiRnn_last_group", "highway_networks",
              "split_1st_concat_last_sharedgroup", "concat_1st_split_last_group", 
               "BiRnn_1st_Concat_last_group", "2_optimizers_diff_subgraph", "test"]

# %%
for model_name in model_names:
    print(f"\n================ model_name = {model_name} ================")
    dl_models.import_model(model_name=model_name, display=True)
# Out:
# ================ model_name = split_1st_concat_last_group ================
# from rztdl.backends import backend
# backend.set('tensorflow')
#
# from rztdl.backends.tensorflow.losses import *
# from rztdl.backends.tensorflow.metrics import *
# from rztdl.backends.tensorflow.helpers.initializers import *
# from rztdl.backends.tensorflow.helpers.regularizers import *
# from rztdl.backends.tensorflow.helpers.activations import *
# from rztdl.backends.tensorflow.optimizers import *
# from rztdl.backends.tensorflow.layers import *
# from rztdl.backends.tensorflow.operators import *
# from rztdl.backends.tensorflow.hub.image.inceptionv3 import InceptionV3
# from rztdl.backends.tensorflow.hub.image.mobilenetv3 import MobileNetV3
# from rztdl.backends.tensorflow.hub.image.resnetv2 import ResNetV2
# from rztdl.backends.tensorflow.hub.text.bert import BERT, BERT_MODEL
# from rztdl.modules.groups.group import Group
# from rztdl.backends.utils.string_constants import *
# ...
