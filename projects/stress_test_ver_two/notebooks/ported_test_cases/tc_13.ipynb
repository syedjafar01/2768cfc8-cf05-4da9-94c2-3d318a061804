# %%
import razor.flow as rf
from razor.api import datasources
import numpy as np
import logging
logger = logging.getLogger()

# %%
@rf.block
class IntType:
    a: int
        
    def run(self):
        logger.info(self.a)

# %%
config = {'cores': 1, 'ram': 4096}

def_type = DefaultType(a=7)
def_type.executor = rf.ContainerExecutor(cores=config['cores'], memory=config['ram'])

pipeline = rf.Pipeline(name='default_integer', targets=[def_type])
pipeline.show()

# %%
def create_pipeline():
    return pipeline
